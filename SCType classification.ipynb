# %% [markdown]
# ## Load libraries, data and functions

# %%
# load libraries 
library(dplyr)
library(Seurat)
library(HGNChelper)
library(openxlsx)
library(ggplot2)
library(tidyverse)
library(igraph)
library(data.tree)
library(ggraph)
library(viridis)
library(stringr)

# load functions
source("https://raw.githubusercontent.com/IanevskiAleksandr/sc-type/master/R/gene_sets_prepare.R")
source("https://raw.githubusercontent.com/IanevskiAleksandr/sc-type/master/R/sctype_score_.R")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, t
#
#
# Please cite our software :)
#
#  Sehyun Oh et al. HGNChelper: identification and correction of invalid gene symbols for human and mouse. F1000Research 2020, 9:1493. DOI: https://doi.org/10.12688/f1000research.28033.1
#
#  Type `citation('HGNChelper')` for a BibTeX entry.
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ lubridate 1.9.4     ✔ tibble    3.3.0
# ✔ purrr     1.1.0     ✔ tidyr     1.3.1
# ✔ readr     2.1.5
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:lubridate’:
#
#     %--%, union
#
#
# The following objects are masked from ‘package:purrr’:
#
#     compose, simplify
#
#
# The following object is masked from ‘package:tidyr’:
#
#     crossing
#
#
# The following object is masked from ‘package:tibble’:
#
#     as_data_frame
#
#
# The following object is masked from ‘package:Seurat’:
#
#     components
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     as_data_frame, groups, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
#
# Attaching package: ‘ggraph’
#
#
# The following object is masked from ‘package:sp’:
#
#     geometry
#
#
# Loading required package: viridisLite

# %%
# get cell-type-specific gene sets (from dataset of markers from research papers)
dir1 = readline(prompt = "Please enter file directory to ScTypeDB_all_markers.xlsx: ")
gs_list = gene_sets_prepare(dir1, "Brain")
gs_list
# Out:
# Please enter file directory to ScTypeDB_all_markers.xlsx:  ../raw_data/ScTypeDB_all_markers.xlsx
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# $gs_positive
# $gs_positive$`Astrocyte-like`
# [1] "ATP1B4" "GJA1"
#
# $gs_positive$`Epithelial/Endothelial Cells`
# [1] "FXYD1"  "IFITM1" "RBP4"   "RGCC"
#
# $gs_positive$Pallium_09
# [1] "BARHL2" "CRHBP"  "ID4"    "LHX5"   "ZFHX3"  "ZFHX4"
#
# $gs_positive$PoA_02
# [1] "CRHBP" "ID4"   "PDYN"  "SCGN"
#
# $gs_positive$PoA_01
# [1] "CBLN1" "GCH1"  "GSC"   "SCGN"  "TRH"
#
# $gs_positive$Subpallium_03
# [1] "ETV1"  "LMO1"  "NXPH1" "SOX6"
#
# $gs_positive$Pallium_IN03
# [1] "CD99L2" "LHX5"   "TUBA1C" "TUBB"   "ZC4H2"
#
# $gs_positive$Progenitor_01
# [1] "CEBPD"
#
# $gs_positive$Progenitor_02
# [1] "CNDP1"   "HSPB1"   "KRT18"   "SLC13A1"
#
# $gs_positive$`NK-like`
# [1] "B2M"   "CEBPB" "PFN1"  "SRGN"
#
# $gs_positive$`Cycling progenitors_02`
# character(0)
#
# $gs_positive$Subpallium_IN
# [1] "CD99L2" "LHX6"   "TUBB2B" "TUBB"   "ZC4H2"
#
# $gs_positive$dHabenula
# [1] "CNIH3"  "G0S2"   "GNG8"   "NWD2"   "POU4F1" "TGFBI"
#
# $gs_positive$vHabenula
# [1] "CSRP2" "ID4"   "KISS1" "LMO3"  "PRKCQ" "RGS16"
#
# $gs_positive$Microglia_pan
# [1] "APOC1" "PFN1"
#
# $gs_positive$OPC_pan
# [1] "OLIG1"  "OLIG2"  "SEMA5A"
#
# $gs_positive$Oligodendrocytes
# [1] "CD59" "HBZ"
#
# $gs_positive$`Olfactory Bulb`
# [1] "APOF" "MDM2"
#
# $gs_positive$`Cycling progenitors_01`
# [1] "HMGN2"
#
# $gs_positive$Committed_pallium_precursors
# [1] "NEUROD4"
#
# $gs_positive$Committed_subpallium_precursors
# character(0)
#
# $gs_positive$Pallium_IN01
# [1] "BHLHE22" "CD99L2"  "DRAXIN"  "TUBA1A"  "TUBB"    "YBX1"    "ZBTB18"
#
# $gs_positive$Pallium_IN02
# [1] "ELAVL4"  "LHX5"    "MAB21L1" "TFAP2E"  "TUBB"
#
# $gs_positive$Pallium_01
# [1] "ARPP21" "EMX1"   "FEZF1"
#
# $gs_positive$Pallium_02
# [1] "CBLN1"  "ELAVL4" "R3HDM1"
#
# $gs_positive$Pallium_03
# [1] "CBLN1"     "NEUROD1"   "RPRML"     "TNFAIP8L3" "TSHZ1"     "ZIC3"
#
# $gs_positive$Pallium_04
# [1] "PDYN"    "RASD1"   "RPRML"   "TMSB15A"
#
# $gs_positive$Pallium_05
# [1] "CHGA"  "DUSP2" "DUSP5"
#
# $gs_positive$Pallium_06
# [1] "BHLHE22" "BHLHE23" "EGR3"    "FAM43B"
#
# $gs_positive$Pallium_07
# [1] "COX8BP"  "IRAG2"   "NEUROD1" "PPP1R1C" "RPRML"
#
# $gs_positive$Pallium_08
# [1] "BARHL2"  "EMX2"    "LHX9"    "MAB21L1" "RPRML"   "UNCX"
#
# $gs_positive$Subpallium_01
# [1] "LHX6" "NPY"  "SOX6"
#
# $gs_positive$Subpallium_02
# [1] "PCP4L1" "SNED1"  "SYNPR"  "TAC1"
#
# $gs_positive$Subpallium_04
# [1] "BSX"     "ONECUT1" "ZIC1"    "ZIC4"
#
# $gs_positive$Subpallium_05
# [1] "CXCL14"  "PCP4L1"  "PDYN"    "PIK3IP1"
#
# $gs_positive$Subpallium_06
# [1] "CALB1"   "GAD2"    "GBX1"    "LHX6"    "SLC32A1" "ZIC1"
#
# $gs_positive$Subpallium_07
# [1] "GAD2"    "RGS4"    "SLC32A1"
#
# $gs_positive$Subpallium_08
# [1] "BHLHE41" "GAD2"    "NECAB1"  "SLC32A1" "SNED1"
#
# $gs_positive$`blood/immune cell`
# [1] "C1QC"  "MFAP4"
#
# $gs_positive$`blood/immune cell (possibly b cells)`
# [1] "ARPC1B" "CORO1A" "LCP1"   "RAC2"
#
# $gs_positive$cornea
# [1] "ALPL"  "FXYD1" "HGD"   "KRT8"  "RBP4"  "TUBB6"
#
# $gs_positive$`cranial nerve neurons`
# character(0)
#
# $gs_positive$diencephalon
# [1] "ATP2A3" "DAZAP1" "DGKH"   "PLXDC1" "SMPX"
#
# $gs_positive$`diencephalon (gabaergic) neurons`
# [1] "CDH8"   "ELAVL4" "FXYD6"  "GAD2"   "LHX5"
#
# $gs_positive$`diencephalon (glutamatergic) neurons`
# [1] "LHX9"   "POU4F2" "RBFOX1"
#
# $gs_positive$`diencephalon neurons_A`
# [1] "BHLHE22" "ELAVL4"  "NEUROD2" "PITX2"   "SNCB"
#
# $gs_positive$`diencephalon neurons_B`
#  [1] "BNC2"    "CD99L2"  "CNTLN"   "ISLR2"   "ONECUT1" "ROBO1"   "SHOX"
#  [8] "SHOX2"   "TCF7L2"  "TFAP2A"  "TUBB"    "ZFHX3"
#
# $gs_positive$`dorsal dienchephalon (thalamus)`
# [1] "ANO2"    "ATR"     "CDH4"    "HAVCR2"  "PPP1R1C" "SYNPR"
#
# $gs_positive$`dorsal dienchephalon (thalamus) neurons_A`
# [1] "BARHL2"  "ISLR2"   "LHX9"    "MAB21L2" "POU3F1"  "POU4F2"  "TCF7L2"
# [8] "TFAP2D"  "TUBB"
#
# $gs_positive$`dorsal dienchephalon (thalamus) neurons_B`
# [1] "BARHL2" "LHX9"   "POU4F2" "TFAP2A" "TFAP2D" "TFAP2E"
#
# $gs_positive$`dorsal habenula`
# [1] "CNIH3"  "G0S2"   "GNG8"   "KCTD4"  "NWD2"   "POU4F1" "RGS8"   "SYNPR"
# [9] "TGFBI"
#
# $gs_positive$`dorsal habenula neurons`
# [1] "BEAN1"  "CADPS2" "CNIH3"  "GNG8"   "NWD2"   "POU4F1" "SYNPR"
#
# $gs_positive$`epithelium (cornea)_A`
# [1] "CRIP1" "FSTL3" "MFAP2"
#
# $gs_positive$`epithelium (cornea)_B`
#  [1] "ANGPTL7" "COL1A2"  "CRIP1"   "IFITM1"  "KRT15"   "KRT18"   "KRT8"
#  [8] "MFAP2"   "RBP4"    "VWDE"
#
# $gs_positive$`erythrocytes)_A`
# [1] "CREG1"  "HBZ"    "NT5DC1"
#
# $gs_positive$erythrocytes_B
# [1] "ALAS2"  "BLVRB"  "HBZ"    "NT5DC1" "RHAG"   "TMOD4"  "UCP3"
#
# $gs_positive$`eye (cornea), cartilage`
#  [1] "COL1A2" "COL9A2" "COL9A3" "CNMD"   "LUM"    "MATN1"  "MATN4"  "MIA"
#  [9] "OGN"    "SPARC"
#
# $gs_positive$`eye (endothelial, epithelium)`
# [1] "ACTA2" "CRIP1" "HYAL4" "MFAP2" "TAGLN" "TPM1"
#
# $gs_positive$`eye (endothelial, progenitors)`
# [1] "ANGPTL3" "AOC2"    "COL4A1"  "RASL12"
#
# $gs_positive$`eye (epidermis)_A`
# [1] "CFD"    "CLDN1"  "COL1A2" "KRT5"   "PFN1"   "THY1"
#
# $gs_positive$`eye (epidermis)_B`
# [1] "TXNDC12" "EPCAM"   "KRT17"   "KRT4"
#
# $gs_positive$`eye (epidermis)_C`
# [1] "CFD"    "COL1A2" "EPCAM"  "ITGA6"  "ITGB4"
#
# $gs_positive$`eye (non retina)_A`
# [1] "EPCAM" "KRT4"  "KRT5"
#
# $gs_positive$`eye (non retina)`
# [1] "COL1A2" "COL6A1" "DCN"    "KERA"   "TNMD"   "TNN"
#
# $gs_positive$glia_A
#  [1] "APOC1"   "APOF"    "ATP1B4"  "BHMT"    "CLU"     "COL18A1" "CP"
#  [8] "RAMP2"   "RBP4"    "SLC13A4"
#
# $gs_positive$glia_B
# [1] "ALDH1A2" "APOF"    "BHMT"    "CARHSP1" "FXYD1"   "CNMD"    "RBP4"
#
# $gs_positive$`glia progenitors`
# [1] "DAW1"    "ENKUR"   "LDLRAD2" "PACRG"   "PLA1A"   "SLC13A1" "SPAG6"
# [8] "TBATA"
#
# $gs_positive$`granule cells (glutamatergic) neurons`
# [1] "POPDC1"   "CBLN1"    "CDK15"    "DLG1"     "NEBL"     "TMEM178A"
#
# $gs_positive$`granule cells (neurons)_A`
#  [1] "BCAM"    "DRAXIN"  "NEBL"    "NEUROD1" "NEUROD2" "TUBB"    "ZBTB18"
#  [8] "ZIC1"    "ZIC4"    "ZIC5"
#
# $gs_positive$`granule cells (neurons)_B`
# [1] "DLG1"    "ELAVL4"  "FAT2"    "GSG1L"   "NEBL"    "NEUROD1" "ZIC1"
# [8] "ZIC5"
#
# $gs_positive$`hindbrain neurons_A`
# [1] "ELAVL3" "ELAVL4" "TUBB"
#
# $gs_positive$`hindbrain neurons_B`
# [1] "CBLN1"  "EYA1"   "PHOX2A" "SHOX2"  "TLX2"
#
# $gs_positive$hypothalamus_A
# [1] "CHGB"   "DDC"    "GCH1"   "NME5"   "POU3F1" "PRDX1"  "SCGN"   "TXN"
#
# $gs_positive$hypothalamus_B
# [1] "CHODL"   "GAD2"    "QPCT"    "SLC32A1" "SNED1"   "SYNPR"   "TAC1"
#
# $gs_positive$hypothalamus_C
# [1] "GPX3" "LHX6" "NPY"  "SOX6" "VGF"
#
# $gs_positive$`hypothalamus neurons_A`
# [1] "CBLN1"  "FEZF1"  "GABRA5" "KCTD4"  "NR0B1"  "PDYN"   "SOX14"  "TAC1"
# [9] "VAT1"
#
# $gs_positive$`hypothalamus neurons_B`
#  [1] "CRHBP"   "DDC"     "ELAVL4"  "FEV"     "GATA3"   "GCH1"    "HTR1D"
#  [8] "PRDX1"   "SLC18A2" "SNCB"    "TH"      "TPH2"    "TXN"
#
# $gs_positive$lens
# [1] "CRYBA4" "CRYBB1" "CRYBB2" "GRIFIN"
#
# $gs_positive$`lens epithelium`
# [1] "ASPH"    "CYP26A1" "FOXE3"   "GCLC"    "GCLM"    "PRSS35"  "SLC7A11"
# [8] "SPARCL1"
#
# $gs_positive$lymphocytes
# [1] "ARPC1B" "CORO1A" "LCP1"   "PFN1"   "RAC2"   "SRGN"
#
# $gs_positive$metaphocytes
# [1] "AGR2"     "BIK"      "EPCAM"    "HEPACAM2" "POU2F3"   "SCGN"     "SPINT2"
# [8] "TPRG1"
#
# $gs_positive$microglia_raj15
# [1] "APOC1"  "G0S2"   "HAVCR1"
#
# $gs_positive$`midbrain neurons`
# [1] "CEBPA" "CEBPB" "DDIT3" "HUNK"  "LHX9"
#
# $gs_positive$`midbrain neurons (glutamatergic)`
# [1] "EMP1"   "TUBB2A"
#
# $gs_positive$`neural crest derived_A`
# [1] "EXOC3L1" "GPNMB"   "GATA3"   "LCN15"   "MYO5B"   "SOX10"   "TFEC"
# [8] "URAHP"
#
# $gs_positive$`neural crest derived_B`
# [1] "BCO1"    "SCARB1"  "TMEM130" "URAHP"
#
# $gs_positive$neurons_A
# [1] "TUBB"
#
# $gs_positive$neurons_B
# [1] "CD99L2" "ELAVL3" "ELAVL4" "TUBB"
#
# $gs_positive$`neurons (ganglion) `
# [1] "EYA1" "EYA4" "PRPH" "TLX2" "VIM"
#
# $gs_positive$`neurons (glutamatergic)`
# [1] "TCF7L2"
#
# $gs_positive$oligodendrocytes_A
# [1] "DHRS12"
#
# $gs_positive$oligodendrocytes_B
# [1] "CLDN19"  "FSTL3"   "GLDN"    "TAMALIN" "NR4A2"   "PHLDA2"
#
# $gs_positive$oligodendrocytes_C
# [1] "CLDN19" "DHRS12" "MPZ"    "NINJ2"  "TIMD4"
#
# $gs_positive$OPC_raj15
#  [1] "BCAN"   "CD226"  "FABP2"  "LY75"   "NINJ2"  "OLIG1"  "OLIG2"  "SEMA5A"
#  [9] "SOX10"  "UGT8"
#
# $gs_positive$`optic tectum (gabaergic)`
# [1] "CAMK2A"  "GAD2"    "NPB"     "PDYN"    "PLXDC1"  "SLC32A1" "TAL1"
#
# $gs_positive$`optic tectum (gabaergic) neurons`
# [1] "EMX2"  "GATA3" "SOX14" "TAL1"  "UNCX"
#
# $gs_positive$`perivascular- FGP cells`
# [1] "CLIC2"  "DAB2"   "ECSCR"  "EHD4"   "GNG10"  "GPR182" "RAMP2"  "STAB2"
#
# $gs_positive$`pigment cell`
# [1] "BACE2"    "DCT"      "GPR143"   "NQO1"     "OCA2"     "PAH"      "SLC39A10"
# [8] "SLC45A2"
#
# $gs_positive$`pigment cell (iridophore)`
# [1] "CMTM6"   "GPNMB"   "MYO5B"   "TPD52L1" "URAHP"
#
# $gs_positive$progenitors_A
# [1] "CCND1" "HELLS" "ERBB2" "LIG1"  "PCNA"
#
# $gs_positive$progenitors_B
# [1] "CCND1"   "CHAF1A"  "CKS1B"   "ERBB2"   "LBR"     "LIG1"    "NMRK2"
# [8] "PCNA"    "SLC29A2"
#
# $gs_positive$progenitors_C
# [1] "PCNA"    "RPA2"    "RPL22L1"
#
# $gs_positive$`progenitors (cycling)_A`
# [1] "ASPM"   "CCNA2"  "CCNB1"  "CDC20"  "CDK1"   "KPNA2"  "NUSAP1" "PLK1"
# [9] "UBE2C"
#
# $gs_positive$`progenitors (cycling)_B`
#  [1] "ASPM"   "CCNA2"  "CDC20"  "CDK1"   "ERBB2"  "KPNA2"  "NUSAP1" "PLK1"
#  [9] "TOP2A"  "TPX2"   "UBE2C"
#
# $gs_positive$`progenitors (ventral)`
# [1] "ATP1B4"  "NKX2-4"  "S1PR1"   "SOX3"    "ZFP36L2"
#
# $gs_positive$`progenitors/differentiating `
# [1] "TUBB"
#
# $gs_positive$`progenitors/neurons (differentiating)`
# [1] "EBF2"   "ELAVL3" "ERBB2"  "HES6"
#
# $gs_positive$`purkinje neurons (gabaergic ++)`
# [1] "ANO2"   "CA8"    "CASQ2"  "DAZAP1" "PCP4L1"
#
# $gs_positive$`radial glia`
# [1] "ATP1B4" "CD63"   "GJA1"   "PTN"    "S100B"  "S1PR1"
#
# $gs_positive$`retina (amacrine, gabaergic) neurons`
# [1] "BHLHE22" "FOXG1"   "SLC32A1" "TFAP2A"  "TFAP2E"  "ZNF395"
#
# $gs_positive$`retina (cone bipolar cells)_A`
# [1] "EML1"  "FOXG1" "VSX1"
#
# $gs_positive$`retina (cone bipolar cells)_B`
# [1] "CRX"     "EML1"    "FOXG1"   "NEUROD4" "PRKCA"   "STX3"    "VSX1"
#
# $gs_positive$`retina (cone bipolar cells)_C`
# [1] "PRKCA"
#
# $gs_positive$`retina (cone bipolar cells)_D`
# [1] "CALB1" "IRX6"  "LHX4"
#
# $gs_positive$`retina (cone bipolar cells)_E`
# [1] "FEZF2"   "FOXG1"   "LHX4"    "NEUROD4" "STX3"    "TNNT1"   "VAMP1"
# [8] "VSX1"
#
# $gs_positive$`retina (cone bipolar cells)_F`
# [1] "EML1"  "FOXG1" "LHX4"  "RGS11"
#
# $gs_positive$`retina (cones)`
# [1] "GNAT2"  "OPN1MW" "PDE6H"
#
# $gs_positive$`retina (horizontal cells)`
# [1] "LGALS3BP" "SLC4A5"
#
# $gs_positive$`retina (muller glia)`
# [1] "CYP26A1" "FOXG1"   "GSTP1"   "MT2A"    "TMPRSS6"
#
# $gs_positive$`retina (photoreceptor precursor cells)`
# [1] "ARL13A"  "CRX"     "NR2E3"   "TMEM244"
#
# $gs_positive$`retina (RGC) - COMBINE WITH cluster38`
# character(0)
#
# $gs_positive$`retina (RGC) neurons`
# [1] "POU4F1"
#
# $gs_positive$`retina (rods)`
# [1] "CNGA1"  "GNAT1"  "GNGT1"  "GUCA1B" "PDE6B"  "PDE6G"
#
# $gs_positive$`retina (RPE)`
# [1] "DCT"    "RBP3"   "MB"     "RBP5"   "RDH5"   "STRA6"  "TM6SF2"
#
# $gs_positive$`retina (starburst amacrine, gabaergic) neurons`
# [1] "CHGB"   "FOXG1"  "GLDN"   "ISM1"   "RGS11"  "RGS9BP"
#
# $gs_positive$`retina neurons`
# [1] "FOXG1"  "GBX2"   "KCND1"  "KIF5C"  "PRDM13" "SLC6A9"
#
# $gs_positive$`retina progenitors_A`
# [1] "BHLHE22" "CRYBA4"  "CRYBB1"  "FOXG1"   "TFAP2A"
#
# $gs_positive$`retina progenitors_B`
# [1] "ATOH7"  "CCND1"  "CHAF1A" "FOXG1"  "FOXN4"  "MKI67"  "NUSAP1"
#
# $gs_positive$`rostral blood island (myeloid)`
# [1] "CLIC2" "KRT18" "PODXL" "RGCC"  "SRGN"
#
# $gs_positive$`telencephalon (gabaergic)`
# [1] "CLSTN2"  "GAD2"    "NGB"     "PDYN"    "PIK3IP1" "PRSS12"  "SLC32A1"
#
# $gs_positive$`telencephalon (pallium, glutamatergic)`
# [1] "AK5"   "CHGA"  "EGR3"  "KCTD4" "RPRML"
#
# $gs_positive$`telencephalon neurons (pallium, differentiating)`
# [1] "CPNE2"  "ELAVL3" "ELAVL4" "ISLR2"
#
# $gs_positive$`torus long neurons`
# [1] "CRLF3"   "FAT2"    "GAL"     "NEUROD1" "TCAP"    "ZIC1"    "ZIC5"
#
# $gs_positive$`URL progenitors`
# [1] "PCLAF"   "NMRK2"   "PCNA"    "RRM2"    "SLC29A2"
#
# $gs_positive$`ventral forebrain (dienc, hyp, poa; gabaergic)_A`
# [1] "GAD2"  "GSX1"  "ISL1"  "ISLR2" "KCTD4" "TAC1"
#
# $gs_positive$`ventral forebrain (dienc, hyp, poa; gabaergic)_B`
# [1] "FXYD6"   "GAD2"    "KCTD4"   "SLC32A1" "VGF"
#
# $gs_positive$`ventral habenula`
#  [1] "AK5"     "AOC1"    "APOA2"   "CSRP2"   "KISS1"   "LMO3"    "NECAB1"
#  [8] "ONECUT1" "PRKCQ"   "RGS8"
#
# $gs_positive$`ALL (DIM++)ProgPProgenitor`
# [1] "NEUROD4"
#
# $gs_positive$`ALL (TEL+, DIM+)ProgPProgenitor`
# [1] "CCND1"  "ERBB2"  "MKI67"  "NUSAP1" "PCNA"   "TPX2"
#
# $gs_positive$`ALLMixN-`
# character(0)
#
# $gs_positive$`ALLMixNCholinergic cells`
# [1] "CBLN2" "LHX9"
#
# $gs_positive$`ALLMixNCranial ganglion`
# [1] "COCH"     "EYA2"     "F10"      "FRZB"     "PDGFRA"   "SERPINF1"
#
# $gs_positive$`ALLNonNeuralEEpendymal cells`
# [1] "CP"      "ALDH7A1"
#
# $gs_positive$ALLNonNeuralMMicroglia
# [1] "APOC1"  "CORO1A" "SLC7A7"
#
# $gs_positive$`ALLNonNeuralNNEndothelial cells`
# [1] "GSTP1"  "KRT8"   "PECAM1" "RGCC"
#
# $gs_positive$`ALLNonNeuralNNEndothelial cells (proliferative)`
# [1] "HEY1"     "SERPINE1"
#
# $gs_positive$ALLNonNeuralNNErythrocytes
# [1] "ALAS2"
#
# $gs_positive$`ALLNonNeuralNNTcell / immune cell`
# [1] "ARPC1B" "CORO1A" "PFN1"   "RGS13"  "ZAP70"
#
# $gs_positive$`ALLOLODifferentiating Oligodendrocyte`
# [1] "C7"    "NINJ2" "OLIG2" "PRDM8" "SOX10" "UGT8"
#
# $gs_positive$ALLProgPProgenitor_a
# [1] "ID1"
#
# $gs_positive$ALLProgPProgenitor_b
# [1] "MKI67" "PCNA"
#
# $gs_positive$`ALLProgPRadial Glia`
# [1] "GJA1"    "MT2A"    "TMPRSS6" "S100B"
#
# $gs_positive$`DIM, RhomOLOOligodendrocyte`
# [1] "CD59"   "DHRS12" "MPZ"    "OLIG2"  "SOX10"  "UGT8"
#
# $gs_positive$`DIM, RhomS3NGranule cells, Glut+`
# [1] "AUTS2"   "CBLN1"   "FOXO1"   "NEUROD1"
#
# $gs_positive$`DIM, RhomS3PRadial Glia (Bergmann Glia)`
# [1] "GJA1"   "PRSS35" "S100B"
#
# $gs_positive$`DIM/RhomS2NMidbrain Glut+ `
# [1] "STMN3" "VAMP1"
#
# $gs_positive$`DIM++, RhomS2NCranial ganglion`
# [1] "MYL12A" "PLXDC1" "SMPX"
#
# $gs_positive$`DIM++, TEL/RhomS2NMidbrain`
# [1] "DDIT3"  "HUNK"   "TCF7L2"
#
# $gs_positive$DIMOLOOPC
# [1] "OLIG1"  "OLIG2"  "SEMA5A" "SOX10"
#
# $gs_positive$`DIMS2NCranial ganglion`
# character(0)
#
# $gs_positive$DIMS2NDiencephalon_a
# [1] "FOXA1" "PITX2"
#
# $gs_positive$DIMS2NDiencephalon_b
# [1] "BHLHE22" "FOXA1"   "PITX2"
#
# $gs_positive$DIMS2NHyp
# [1] "CHGB"  "DDC"   "PRDX1" "SCG3"
#
# $gs_positive$DIMS2NMidbrain_a
#  [1] "BARHL2" "LEF1"   "LHX9"   "POU3F1" "POU4F1" "POU4F2" "TFAP2A" "TFAP2B"
#  [9] "TFAP2D" "TFAP2E"
#
# $gs_positive$DIMS2NMidbrain_b
# [1] "BARHL2"  "BNC2"    "ISLR2"   "ONECUT1" "ROBO1"   "SHOX2"   "TCF7L2"
# [8] "TFAP2A"
#
# $gs_positive$`DIMS2NMidbrain/Thalamus`
# [1] "BARHL2" "HUNK"   "LEF1"   "LHX9"   "POU3F1" "POU4F1" "POU4F2" "SOX6"
# [9] "TCF7L2"
#
# $gs_positive$`DIMS2NOptic Tectum`
# [1] "EMX2"  "GATA3" "LHX5"  "TAL1"
#
# $gs_positive$`DIMS2NOptic Tectum Gaba +++ _a`
# [1] "GAD2"    "NGEF"    "NPB"     "PDYN"    "SLC32A1" "TAL1"
#
# $gs_positive$`DIMS2NOptic Tectum Gaba+ _a`
# [1] "EGR3"  "EMX2"  "LMO1"  "OTX2"  "SOX12" "SOX14" "TAL1"
#
# $gs_positive$`DIMS2NOptic Tectum Gaba+_b`
# [1] "EMX2"   "GATA3"  "LHX5"   "OTX2"   "SOX14"  "TAL1"   "TFAP2B" "UNCX"
#
# $gs_positive$`DIMS2NOptic Tectum Gaba+++_b`
# [1] "GAD2"    "OTX2"    "SLC32A1" "TAL1"
#
# $gs_positive$`DIMS2NTorus Longitudinalis_a`
# [1] "FAT2"    "GAL"     "NEUROD1" "NEUROD2" "TCAP"
#
# $gs_positive$`DIMS2NTorus Longitudinalis 2`
# [1] "FAT2"    "NEBL"    "NEUROD1" "OTX2"    "POU4F2"  "ZIC5"
#
# $gs_positive$`DIMS2POptic Tectum Radial Glia`
# [1] "GJA1"  "S1PR1"
#
# $gs_positive$`NAS1NPineal gland`
# [1] "GNAT1" "GNGT1" "RBP3"  "PDE6G" "TPH2"
#
# $gs_positive$`Rhom++, DIMProgPURL Progenitor`
# [1] "MKI67"   "NEUROD1" "NUSAP1"  "PCNA"
#
# $gs_positive$`Rhom++, DIMS3NGranule  cells_a`
# [1] "FAT2"    "NEBL"    "NEUROD1" "NEUROD2"
#
# $gs_positive$`Rhom++, DIMS3NGranule cell _b`
# [1] "NEUROD1" "NEUROD2" "ZIC5"
#
# $gs_positive$`Rhom++, DIMS3NGranule cells_c`
# [1] "FAT2"    "GSG1L"   "NEUROD1" "TAC1"
#
# $gs_positive$`RhomS3NGaba+ Hindbrain`
# [1] "GAD2"    "LHX5"    "NEUROD1" "SLC32A1"
#
# $gs_positive$`RhomS3NPhox2+ Hindbrain cells`
# [1] "PHOX2A" "SHOX2"  "TLX2"
#
# $gs_positive$`RhomS3NPurkinje cells`
# [1] "CA8"
#
# $gs_positive$`RhomS3NStatoacoustic ganglion`
# [1] "TLN1"
#
# $gs_positive$`TEL, DIM ++S2NMidbrain/Thalamus`
# [1] "BARHL2" "LHX9"   "TCF7L2"
#
# $gs_positive$`TEL, DIMS1NHyp`
# [1] "FEZF1" "KCTD4" "LHX5"  "PDYN"
#
# $gs_positive$`TEL, DIMS1NHyp, Gaba+`
# [1] "GSX1" "HMX2" "ISL1"
#
# $gs_positive$`TEL, DIMS1NSubpallium Gaba+ `
# [1] "FOXG1" "GAD2"  "ISL1"  "LHX6"
#
# $gs_positive$`TEL, DIMS1NVentral Forebrain, Gaba+++, Glut+`
# [1] "GAD2"    "SLC32A1"
#
# $gs_positive$`TEL/DIMNonNeuralNNPerivascular- FGP cells`
# [1] "EGFL7" "FLT4"  "STAB1" "STAB2"
#
# $gs_positive$`TEL/DIMS1NDorsal Habenula`
# [1] "ANO2"  "G0S2"  "GNG8"  "NWD2"  "SYNPR"
#
# $gs_positive$`TEL/DIMS1NTelencephalon, Glut+`
# [1] "LHX5" "UNCX"
#
# $gs_positive$`TEL/DIMS1NVentral Habenula`
# [1] "KISS1" "PRKCQ"
#
# $gs_positive$`TEL+, DIMS1N-`
# [1] "CAMK2A" "NGEF"   "PRKD1"
#
# $gs_positive$`TEL++, DIM++, RhomS1/S2NNascent neurons`
# [1] "NR2F2"  "TUBB"   "ZBTB18"
#
# $gs_positive$TELS1NHyp_a
# [1] "GAD2"    "HLCS"    "PCP4L1"  "SLC32A1" "SNED1"   "SYNPR"   "TAC1"
#
# $gs_positive$TELS1NHyp_b
# [1] "FOXG1" "GAB2"  "GAD2"  "LHX6"  "NPY"
#
# $gs_positive$`TELS1NHyp/POA`
# [1] "FOXG1"   "PDYN"    "SLC32A1"
#
# $gs_positive$TELS1NPallium_a
# [1] "CBLN1"
#
# $gs_positive$TELS1NPallium_b
# [1] "FOXG1"   "NEUROD1"
#
# $gs_positive$`TELS1NPallium (Glut+)`
# [1] "BHLHE22" "GABRB3"  "GEM"     "NGB"
#
#
# $gs_negative
# $gs_negative$`Astrocyte-like`
# character(0)
#
# $gs_negative$`Epithelial/Endothelial Cells`
# character(0)
#
# $gs_negative$Pallium_09
# character(0)
#
# $gs_negative$PoA_02
# character(0)
#
# $gs_negative$PoA_01
# character(0)
#
# $gs_negative$Subpallium_03
# character(0)
#
# $gs_negative$Pallium_IN03
# character(0)
#
# $gs_negative$Progenitor_01
# character(0)
#
# $gs_negative$Progenitor_02
# character(0)
#
# $gs_negative$`NK-like`
# character(0)
#
# $gs_negative$`Cycling progenitors_02`
# character(0)
#
# $gs_negative$Subpallium_IN
# character(0)
#
# $gs_negative$dHabenula
# character(0)
#
# $gs_negative$vHabenula
# character(0)
#
# $gs_negative$Microglia_pan
# character(0)
#
# $gs_negative$OPC_pan
# character(0)
#
# $gs_negative$Oligodendrocytes
# character(0)
#
# $gs_negative$`Olfactory Bulb`
# character(0)
#
# $gs_negative$`Cycling progenitors_01`
# character(0)
#
# $gs_negative$Committed_pallium_precursors
# character(0)
#
# $gs_negative$Committed_subpallium_precursors
# character(0)
#
# $gs_negative$Pallium_IN01
# character(0)
#
# $gs_negative$Pallium_IN02
# character(0)
#
# $gs_negative$Pallium_01
# character(0)
#
# $gs_negative$Pallium_02
# character(0)
#
# $gs_negative$Pallium_03
# character(0)
#
# $gs_negative$Pallium_04
# character(0)
#
# $gs_negative$Pallium_05
# character(0)
#
# $gs_negative$Pallium_06
# character(0)
#
# $gs_negative$Pallium_07
# character(0)
#
# $gs_negative$Pallium_08
# character(0)
#
# $gs_negative$Subpallium_01
# character(0)
#
# $gs_negative$Subpallium_02
# character(0)
#
# $gs_negative$Subpallium_04
# character(0)
#
# $gs_negative$Subpallium_05
# character(0)
#
# $gs_negative$Subpallium_06
# character(0)
#
# $gs_negative$Subpallium_07
# character(0)
#
# $gs_negative$Subpallium_08
# character(0)
#
# $gs_negative$`blood/immune cell`
# character(0)
#
# $gs_negative$`blood/immune cell (possibly b cells)`
# character(0)
#
# $gs_negative$cornea
# character(0)
#
# $gs_negative$`cranial nerve neurons`
# character(0)
#
# $gs_negative$diencephalon
# character(0)
#
# $gs_negative$`diencephalon (gabaergic) neurons`
# character(0)
#
# $gs_negative$`diencephalon (glutamatergic) neurons`
# character(0)
#
# $gs_negative$`diencephalon neurons_A`
# character(0)
#
# $gs_negative$`diencephalon neurons_B`
# character(0)
#
# $gs_negative$`dorsal dienchephalon (thalamus)`
# character(0)
#
# $gs_negative$`dorsal dienchephalon (thalamus) neurons_A`
# character(0)
#
# $gs_negative$`dorsal dienchephalon (thalamus) neurons_B`
# character(0)
#
# $gs_negative$`dorsal habenula`
# character(0)
#
# $gs_negative$`dorsal habenula neurons`
# character(0)
#
# $gs_negative$`epithelium (cornea)_A`
# character(0)
#
# $gs_negative$`epithelium (cornea)_B`
# character(0)
#
# $gs_negative$`erythrocytes)_A`
# character(0)
#
# $gs_negative$erythrocytes_B
# character(0)
#
# $gs_negative$`eye (cornea), cartilage`
# character(0)
#
# $gs_negative$`eye (endothelial, epithelium)`
# character(0)
#
# $gs_negative$`eye (endothelial, progenitors)`
# character(0)
#
# $gs_negative$`eye (epidermis)_A`
# character(0)
#
# $gs_negative$`eye (epidermis)_B`
# character(0)
#
# $gs_negative$`eye (epidermis)_C`
# character(0)
#
# $gs_negative$`eye (non retina)_A`
# character(0)
#
# $gs_negative$`eye (non retina)`
# character(0)
#
# $gs_negative$glia_A
# character(0)
#
# $gs_negative$glia_B
# character(0)
#
# $gs_negative$`glia progenitors`
# character(0)
#
# $gs_negative$`granule cells (glutamatergic) neurons`
# character(0)
#
# $gs_negative$`granule cells (neurons)_A`
# character(0)
#
# $gs_negative$`granule cells (neurons)_B`
# character(0)
#
# $gs_negative$`hindbrain neurons_A`
# character(0)
#
# $gs_negative$`hindbrain neurons_B`
# character(0)
#
# $gs_negative$hypothalamus_A
# character(0)
#
# $gs_negative$hypothalamus_B
# character(0)
#
# $gs_negative$hypothalamus_C
# character(0)
#
# $gs_negative$`hypothalamus neurons_A`
# character(0)
#
# $gs_negative$`hypothalamus neurons_B`
# character(0)
#
# $gs_negative$lens
# character(0)
#
# $gs_negative$`lens epithelium`
# character(0)
#
# $gs_negative$lymphocytes
# character(0)
#
# $gs_negative$metaphocytes
# character(0)
#
# $gs_negative$microglia_raj15
# character(0)
#
# $gs_negative$`midbrain neurons`
# character(0)
#
# $gs_negative$`midbrain neurons (glutamatergic)`
# character(0)
#
# $gs_negative$`neural crest derived_A`
# character(0)
#
# $gs_negative$`neural crest derived_B`
# character(0)
#
# $gs_negative$neurons_A
# character(0)
#
# $gs_negative$neurons_B
# character(0)
#
# $gs_negative$`neurons (ganglion) `
# character(0)
#
# $gs_negative$`neurons (glutamatergic)`
# character(0)
#
# $gs_negative$oligodendrocytes_A
# character(0)
#
# $gs_negative$oligodendrocytes_B
# character(0)
#
# $gs_negative$oligodendrocytes_C
# character(0)
#
# $gs_negative$OPC_raj15
# character(0)
#
# $gs_negative$`optic tectum (gabaergic)`
# character(0)
#
# $gs_negative$`optic tectum (gabaergic) neurons`
# character(0)
#
# $gs_negative$`perivascular- FGP cells`
# character(0)
#
# $gs_negative$`pigment cell`
# character(0)
#
# $gs_negative$`pigment cell (iridophore)`
# character(0)
#
# $gs_negative$progenitors_A
# character(0)
#
# $gs_negative$progenitors_B
# character(0)
#
# $gs_negative$progenitors_C
# character(0)
#
# $gs_negative$`progenitors (cycling)_A`
# character(0)
#
# $gs_negative$`progenitors (cycling)_B`
# character(0)
#
# $gs_negative$`progenitors (ventral)`
# character(0)
#
# $gs_negative$`progenitors/differentiating `
# character(0)
#
# $gs_negative$`progenitors/neurons (differentiating)`
# character(0)
#
# $gs_negative$`purkinje neurons (gabaergic ++)`
# character(0)
#
# $gs_negative$`radial glia`
# character(0)
#
# $gs_negative$`retina (amacrine, gabaergic) neurons`
# character(0)
#
# $gs_negative$`retina (cone bipolar cells)_A`
# character(0)
#
# $gs_negative$`retina (cone bipolar cells)_B`
# character(0)
#
# $gs_negative$`retina (cone bipolar cells)_C`
# character(0)
#
# $gs_negative$`retina (cone bipolar cells)_D`
# character(0)
#
# $gs_negative$`retina (cone bipolar cells)_E`
# character(0)
#
# $gs_negative$`retina (cone bipolar cells)_F`
# character(0)
#
# $gs_negative$`retina (cones)`
# character(0)
#
# $gs_negative$`retina (horizontal cells)`
# character(0)
#
# $gs_negative$`retina (muller glia)`
# character(0)
#
# $gs_negative$`retina (photoreceptor precursor cells)`
# character(0)
#
# $gs_negative$`retina (RGC) - COMBINE WITH cluster38`
# character(0)
#
# $gs_negative$`retina (RGC) neurons`
# character(0)
#
# $gs_negative$`retina (rods)`
# character(0)
#
# $gs_negative$`retina (RPE)`
# character(0)
#
# $gs_negative$`retina (starburst amacrine, gabaergic) neurons`
# character(0)
#
# $gs_negative$`retina neurons`
# character(0)
#
# $gs_negative$`retina progenitors_A`
# character(0)
#
# $gs_negative$`retina progenitors_B`
# character(0)
#
# $gs_negative$`rostral blood island (myeloid)`
# character(0)
#
# $gs_negative$`telencephalon (gabaergic)`
# character(0)
#
# $gs_negative$`telencephalon (pallium, glutamatergic)`
# character(0)
#
# $gs_negative$`telencephalon neurons (pallium, differentiating)`
# character(0)
#
# $gs_negative$`torus long neurons`
# character(0)
#
# $gs_negative$`URL progenitors`
# character(0)
#
# $gs_negative$`ventral forebrain (dienc, hyp, poa; gabaergic)_A`
# character(0)
#
# $gs_negative$`ventral forebrain (dienc, hyp, poa; gabaergic)_B`
# character(0)
#
# $gs_negative$`ventral habenula`
# character(0)
#
# $gs_negative$`ALL (DIM++)ProgPProgenitor`
# character(0)
#
# $gs_negative$`ALL (TEL+, DIM+)ProgPProgenitor`
# character(0)
#
# $gs_negative$`ALLMixN-`
# character(0)
#
# $gs_negative$`ALLMixNCholinergic cells`
# character(0)
#
# $gs_negative$`ALLMixNCranial ganglion`
# character(0)
#
# $gs_negative$`ALLNonNeuralEEpendymal cells`
# character(0)
#
# $gs_negative$ALLNonNeuralMMicroglia
# character(0)
#
# $gs_negative$`ALLNonNeuralNNEndothelial cells`
# character(0)
#
# $gs_negative$`ALLNonNeuralNNEndothelial cells (proliferative)`
# character(0)
#
# $gs_negative$ALLNonNeuralNNErythrocytes
# character(0)
#
# $gs_negative$`ALLNonNeuralNNTcell / immune cell`
# character(0)
#
# $gs_negative$`ALLOLODifferentiating Oligodendrocyte`
# character(0)
#
# $gs_negative$ALLProgPProgenitor_a
# character(0)
#
# $gs_negative$ALLProgPProgenitor_b
# character(0)
#
# $gs_negative$`ALLProgPRadial Glia`
# character(0)
#
# $gs_negative$`DIM, RhomOLOOligodendrocyte`
# character(0)
#
# $gs_negative$`DIM, RhomS3NGranule cells, Glut+`
# character(0)
#
# $gs_negative$`DIM, RhomS3PRadial Glia (Bergmann Glia)`
# character(0)
#
# $gs_negative$`DIM/RhomS2NMidbrain Glut+ `
# character(0)
#
# $gs_negative$`DIM++, RhomS2NCranial ganglion`
# character(0)
#
# $gs_negative$`DIM++, TEL/RhomS2NMidbrain`
# character(0)
#
# $gs_negative$DIMOLOOPC
# character(0)
#
# $gs_negative$`DIMS2NCranial ganglion`
# character(0)
#
# $gs_negative$DIMS2NDiencephalon_a
# character(0)
#
# $gs_negative$DIMS2NDiencephalon_b
# character(0)
#
# $gs_negative$DIMS2NHyp
# character(0)
#
# $gs_negative$DIMS2NMidbrain_a
# character(0)
#
# $gs_negative$DIMS2NMidbrain_b
# character(0)
#
# $gs_negative$`DIMS2NMidbrain/Thalamus`
# character(0)
#
# $gs_negative$`DIMS2NOptic Tectum`
# character(0)
#
# $gs_negative$`DIMS2NOptic Tectum Gaba +++ _a`
# character(0)
#
# $gs_negative$`DIMS2NOptic Tectum Gaba+ _a`
# character(0)
#
# $gs_negative$`DIMS2NOptic Tectum Gaba+_b`
# character(0)
#
# $gs_negative$`DIMS2NOptic Tectum Gaba+++_b`
# character(0)
#
# $gs_negative$`DIMS2NTorus Longitudinalis_a`
# character(0)
#
# $gs_negative$`DIMS2NTorus Longitudinalis 2`
# character(0)
#
# $gs_negative$`DIMS2POptic Tectum Radial Glia`
# character(0)
#
# $gs_negative$`NAS1NPineal gland`
# character(0)
#
# $gs_negative$`Rhom++, DIMProgPURL Progenitor`
# character(0)
#
# $gs_negative$`Rhom++, DIMS3NGranule  cells_a`
# character(0)
#
# $gs_negative$`Rhom++, DIMS3NGranule cell _b`
# character(0)
#
# $gs_negative$`Rhom++, DIMS3NGranule cells_c`
# character(0)
#
# $gs_negative$`RhomS3NGaba+ Hindbrain`
# character(0)
#
# $gs_negative$`RhomS3NPhox2+ Hindbrain cells`
# character(0)
#
# $gs_negative$`RhomS3NPurkinje cells`
# character(0)
#
# $gs_negative$`RhomS3NStatoacoustic ganglion`
# character(0)
#
# $gs_negative$`TEL, DIM ++S2NMidbrain/Thalamus`
# character(0)
#
# $gs_negative$`TEL, DIMS1NHyp`
# character(0)
#
# $gs_negative$`TEL, DIMS1NHyp, Gaba+`
# character(0)
#
# $gs_negative$`TEL, DIMS1NSubpallium Gaba+ `
# character(0)
#
# $gs_negative$`TEL, DIMS1NVentral Forebrain, Gaba+++, Glut+`
# character(0)
#
# $gs_negative$`TEL/DIMNonNeuralNNPerivascular- FGP cells`
# character(0)
#
# $gs_negative$`TEL/DIMS1NDorsal Habenula`
# character(0)
#
# $gs_negative$`TEL/DIMS1NTelencephalon, Glut+`
# character(0)
#
# $gs_negative$`TEL/DIMS1NVentral Habenula`
# character(0)
#
# $gs_negative$`TEL+, DIMS1N-`
# character(0)
#
# $gs_negative$`TEL++, DIM++, RhomS1/S2NNascent neurons`
# character(0)
#
# $gs_negative$TELS1NHyp_a
# character(0)
#
# $gs_negative$TELS1NHyp_b
# character(0)
#
# $gs_negative$`TELS1NHyp/POA`
# character(0)
#
# $gs_negative$TELS1NPallium_a
# character(0)
#
# $gs_negative$TELS1NPallium_b
# character(0)
#
# $gs_negative$`TELS1NPallium (Glut+)`
# character(0)

# %%
# load data from normalisation and dimensional reduction script
dir = readline(prompt = "Please enter file directory to LOG_NORM_NOVOALL_filt_final: ")
LOG_NORM_NOVOALL_filt_final = readRDS(dir)
# Out:
# Please enter file directory to LOG_NORM_NOVOALL_filt_final:  ../data_files/LOG_NORM_NOVOALL_filt_final.rds

# %% [markdown]
# ## Assign cell types to each cluster

# %%
# check Seurat object version (scRNA-seq matrix extracted differently in Seurat v4/v5)
seurat_package_v5 = isFALSE('counts' %in% names(attributes(LOG_NORM_NOVOALL_filt_final[["RNA"]])));
print(sprintf("Seurat object %s is used", ifelse(seurat_package_v5, "v5", "v4")))

# extract scaled scRNA-seq matrix
scRNAseqData_scaled <- if (seurat_package_v5) as.matrix(LOG_NORM_NOVOALL_filt_final[["RNA"]]$scale.data) else as.matrix(LOG_NORM_NOVOALL_filt_final[["RNA"]]@scale.data)

# run ScType
es.max <- sctype_score(scRNAseqData = scRNAseqData_scaled, scaled = TRUE, gs = gs_list$gs_positive, gs2 = gs_list$gs_negative)

# NOTE: scRNAseqData parameter should correspond to your input scRNA-seq matrix. For raw (unscaled) count matrix set scaled = FALSE
# When using Seurat, we use "RNA" slot with 'scale.data' by default. Please change "RNA" to "SCT" for sctransform-normalized data,
# or to "integrated" for joint dataset analysis. To apply sctype with unscaled data, use e.g. pbmc[["RNA"]]$counts or pbmc[["RNA"]]@counts, with scaled set to FALSE.

# merge by cluster (do.call combines the results for all clusters row by row using rbind into a single df) 
cL_results = do.call("rbind", lapply(unique(LOG_NORM_NOVOALL_filt_final@meta.data$seurat_clusters), function(cl){ # apply the function to every unique cluster id
    es.max.cl = sort(rowSums(es.max[ ,rownames(LOG_NORM_NOVOALL_filt_final@meta.data[LOG_NORM_NOVOALL_filt_final@meta.data$seurat_clusters==cl, ])]), # find the cells in cluster cl and compute row sums of es.max restricted to those cells
                     decreasing = !0) # sort in descending order (highest score first)

    # make dataframe of the top 10 features (classifications) for each cluster
    head(data.frame(cluster = cl, 
                    type = names(es.max.cl), 
                    scores = es.max.cl, # sum of scores for this cluster
                    ncells = sum(LOG_NORM_NOVOALL_filt_final@meta.data$seurat_clusters==cl)), 10) # number of cells in the cluster, keep only top 10 
}))

sctype_scores = cL_results %>%
                group_by(cluster) %>% 
                top_n(n = 1, wt = scores) # wt is the variable used for ordering

# set low-confident (low ScType score) clusters to "unknown"
sctype_scores$type[as.numeric(as.character(sctype_scores$scores)) < sctype_scores$ncells/4] <- "Unknown"
# Out:
# [1] "Seurat object v5 is used"

# %% [markdown]
# ## Overlay identified cell types on UMAP

# %%
LOG_NORM_NOVOALL_filt_final@meta.data$sctype_classification = "" # create new column
for(j in unique(sctype_scores$cluster)){
  cl_type = sctype_scores[sctype_scores$cluster==j,]; # cell type annotation for cluster j 
  LOG_NORM_NOVOALL_filt_final@meta.data$sctype_classification[LOG_NORM_NOVOALL_filt_final@meta.data$seurat_clusters == j] = as.character(cl_type$type[1]) # for all cells whose cluster id = j, add the cell type classification
}

# %%
reduction_name = readline(prompt = "Enter the reduction name, this is \"umap_unintegrated_[chosen final resolution]\", e.g umap_unintegrated_0.8. ")
overlayed_umap = DimPlot(LOG_NORM_NOVOALL_filt_final, 
                         reduction = reduction_name, 
                         label = TRUE, repel = TRUE, label.size = 5, group.by = "sctype_classification")
# Out:
# Enter the reduction name, this is "umap_unintegrated_[chosen final resolution]", e.g umap_unintegrated_0.8.  umap_unintegrated_0.8
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`

# %%
 ggsave("overlayed_umap.png", overlayed_umap, width = 25, height = 25, units = "in", dpi = 300)

# %%
# save LOG_NORM_NOVOALL_filt_final after adding the cell type classification
dir2 = readline(prompt = "Please enter the file directory to save LOG_NORM_NOVOALL_filt_final")
saveRDS(LOG_NORM_NOVOALL_filt_final, file = dir2)
# Out:
# Please enter the file directory to save LOG_NORM_NOVOALL_filt_final ../data_files/LOG_NORM_NOVOALL_filt_final.rds

# %% [markdown]
# ## Bubble plot

# %%
# prepare edges
cL_results <- cL_results[order(cL_results$cluster),]
edges = cL_results
edges$type = paste0(edges$type,"_",edges$cluster)
edges$cluster = paste0("cluster ", edges$cluster)
edges = edges[,c("cluster", "type")]
colnames(edges) = c("from", "to") 
rownames(edges) <- NULL # remove the row names

# prepare nodes
nodes_lvl1 <- sctype_scores[,c("cluster", "ncells")]
nodes_lvl1$cluster = paste0("cluster ", nodes_lvl1$cluster)
nodes_lvl1$Colour = "#f1f1ef"
nodes_lvl1$ord = 1
nodes_lvl1$realname = nodes_lvl1$cluster
nodes_lvl1 = as.data.frame(nodes_lvl1)
nodes_lvl2 = c(); 
ccolss = plasma(39)
for (i in 1:length(unique(cL_results$cluster))){ # iterate over the cluster numbers
    dt_tmp = cL_results[cL_results$cluster == unique(cL_results$cluster)[i], ]
    nodes_lvl2 = rbind(nodes_lvl2, data.frame(cluster = paste0(dt_tmp$type,"_",dt_tmp$cluster), ncells = dt_tmp$scores, Colour = ccolss[i], ord = 2, realname = dt_tmp$type))
}

nodes <- rbind(nodes_lvl1, nodes_lvl2)
nodes$ncells[nodes$ncells<1] = 1 # make all of the scores less than 1 = 1
files_db <- read.xlsx(dir1)[,c("cellName","shortName")]
files_db = unique(files_db)
nodes = merge(nodes, files_db, all.x = T, all.y = F, by.x = "realname", by.y = "cellName", sort = F) %>% # left join, keep all the rows from nodes and matching rows from files_db based on the columns realname (from nodes) and cellName (from files_db)
        distinct() # there was one repeated row so remove it 
nodes$shortName[is.na(nodes$shortName)] = nodes$realname[is.na(nodes$shortName)] 
nodes = nodes[,c("cluster", "ncells", "Colour", "ord", "shortName", "realname")]

mygraph <- graph_from_data_frame(edges, vertices=nodes)

# Make the graph
gggr <- ggraph(mygraph, layout = 'circlepack', weight=I(ncells)) + 
    geom_node_circle(aes(filter=ord==1,fill=I("#F5F5F5"), colour=I("#D3D3D3")), alpha=0.9) + 
    geom_node_circle(aes(filter=ord==2,fill=I(Colour), colour=I("#D3D3D3")), alpha=0.9) +
    theme_void() + 
    geom_node_text(aes(filter=ord==2, label = str_wrap(shortName, 10), colour=I("#ffffff"), fill="white", repel = TRUE, parse = T, size = I(log(ncells,25)*1.5))) + 
    geom_node_label(aes(filter=ord==1,  label = str_wrap(shortName, 10), colour=I("#000000"), size = I(3), fill="white", parse = T, repel = TRUE), segment.linetype="dotted") +
    theme(legend.position = "none")
  
bubble_umap_plot = DimPlot(LOG_NORM_NOVOALL_filt_final, reduction = "umap_unintegrated_0.8", 
                      label = TRUE, repel = TRUE, label.size = 5,
                      cols = ccolss, group.by = "sctype_classification") + gggr
# Out:
# Non-leaf weights ignored
# Warning message in geom_node_text(aes(filter = ord == 2, label = str_wrap(shortName, :
# “Ignoring unknown aesthetics: fill, repel, and parse”
# Warning message in geom_node_label(aes(filter = ord == 1, label = str_wrap(shortName, :
# “Ignoring unknown parameters: `segment.linetype`”
# Warning message in geom_node_label(aes(filter = ord == 1, label = str_wrap(shortName, :
# “Ignoring unknown aesthetics: parse and repel”
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`

# %%
ggsave("bubble_plot.png", gggr, width = 30, height = 30, units = "in", dpi = 300, limitsize = FALSE)

# %%
ggsave("bubble_umap_plot.png", bubble_umap_plot, width = 70, height = 30, units = "in", dpi = 300, limitsize = FALSE)

# %% [markdown]
# ## Optional - combining clusters (This section is a work in progress)
# To combine clusters if their classification is the same.
# Work in progress bc doesnt work for "..._A, ..._B"

# %%
LOG_NORM_NOVOALL_filt_final@meta.data %>% distinct(sctype_classification, seurat_clusters)
# Out:
#                          sctype_classification
# WT_S1_AAACCCAAGGTTAAAC-1 radial glia
# WT_S1_AAACCCAAGTTACGGG-1 ALLNonNeuralMMicroglia
# WT_S1_AAACCCACAAACTCGT-1 diencephalon neurons_B
# WT_S1_AAACCCACAAAGGGTC-1 hypothalamus_A
# WT_S1_AAACCCATCCGACAGC-1 Pallium_06
# WT_S1_AAACCCATCTGCGAGC-1 ALLOLODifferentiating Oligodendrocyte
# WT_S1_AAACCCATCTTCCAGC-1 NK-like
# WT_S1_AAACGAAAGAATAACC-1 dorsal habenula neurons
# WT_S1_AAACGAAAGCCTGACC-1 Subpallium_08
# WT_S1_AAACGAAAGGACACTG-1 TEL, DIM ++S2NMidbrain/Thalamus
# WT_S1_AAACGAAAGGTACAGC-1 granule cells (neurons)_A
# WT_S1_AAACGAACATACAGAA-1 DIMOLOOPC
# WT_S1_AAACGAATCAAGTCGT-1 perivascular- FGP cells
# WT_S1_AAACGAATCGAGATAA-1 Pallium_02
# WT_S1_AAACGCTAGGGATGTC-1 diencephalon
# WT_S1_AAACGCTCATTACTCT-1 optic tectum (gabaergic)
# WT_S1_AAACGCTGTGAGTAGC-1 diencephalon neurons_B
# WT_S1_AAACGCTTCATGAGAA-1 DIM, RhomOLOOligodendrocyte
# WT_S1_AAACGCTTCATGTCAG-1 Subpallium_02
# WT_S1_AAACGCTTCGTCCTCA-1 rostral blood island (myeloid)
# WT_S1_AAAGGATAGCTCAGAG-1 granule cells (neurons)_B
# WT_S1_AAAGGGCCACACGCCA-1 diencephalon neurons_A
# WT_S1_AAAGGTAAGCGCCGTT-1 retina (photoreceptor precursor cells)
# WT_S1_AAAGTCCGTCGCTTAA-1 vHabenula
# WT_S1_AAAGTGAAGGTGCAGT-1 progenitors (cycling)_B
# WT_S1_AAAGTGAGTGTGACCC-1 TEL+, DIMS1N-
# WT_S1_AACAAAGAGATCGCCC-1 lymphocytes
# WT_S1_AACAGGGGTCGCAACC-1 glia_B
# WT_S1_AACAGGGTCCATAGAC-1 ventral forebrain (dienc, hyp, poa; gabaergic)_B
# WT_S1_AACCACACAGACACCC-1 DIM, RhomOLOOligodendrocyte
# WT_S1_AAGACAACACATATGC-1 radial glia
# WT_S1_AAGACTCTCAAAGGAT-1 hypothalamus neurons_A
# WT_S1_AAGGTAATCCTGTACC-1 radial glia
# WT_S1_AAGTTCGTCTACCCAC-1 ventral habenula
# WT_S1_AATCGTGTCGGCCAAC-1 eye (endothelial, progenitors)
# WT_S1_AATGGCTTCTCATGGA-1 DIM, RhomS3PRadial Glia (Bergmann Glia)
# WT_S1_AATTTCCGTTTACTTC-1 progenitors (cycling)_B
# WT_S1_AGACACTGTACCTTCC-1 DIM, RhomOLOOligodendrocyte
# WT_S1_ATTACTCTCAGCACCG-1 NK-like
#                          seurat_clusters
# WT_S1_AAACCCAAGGTTAAAC-1 8
# WT_S1_AAACCCAAGTTACGGG-1 9
# WT_S1_AAACCCACAAACTCGT-1 19
# WT_S1_AAACCCACAAAGGGTC-1 12
# WT_S1_AAACCCATCCGACAGC-1 1
# WT_S1_AAACCCATCTGCGAGC-1 20
# WT_S1_AAACCCATCTTCCAGC-1 6
# WT_S1_AAACGAAAGAATAACC-1 26
# WT_S1_AAACGAAAGCCTGACC-1 3
# WT_S1_AAACGAAAGGACACTG-1 0
# WT_S1_AAACGAAAGGTACAGC-1 5
# WT_S1_AAACGAACATACAGAA-1 7
# WT_S1_AAACGAATCAAGTCGT-1 21
# WT_S1_AAACGAATCGAGATAA-1 24
# WT_S1_AAACGCTAGGGATGTC-1 29
# WT_S1_AAACGCTCATTACTCT-1 10
# WT_S1_AAACGCTGTGAGTAGC-1 17
# WT_S1_AAACGCTTCATGAGAA-1 2
# WT_S1_AAACGCTTCATGTCAG-1 25
# WT_S1_AAACGCTTCGTCCTCA-1 13
# WT_S1_AAAGGATAGCTCAGAG-1 4
# WT_S1_AAAGGGCCACACGCCA-1 11
# WT_S1_AAAGGTAAGCGCCGTT-1 37
# WT_S1_AAAGTCCGTCGCTTAA-1 23
# WT_S1_AAAGTGAAGGTGCAGT-1 22
# WT_S1_AAAGTGAGTGTGACCC-1 28
# WT_S1_AACAAAGAGATCGCCC-1 15
# WT_S1_AACAGGGGTCGCAACC-1 27
# WT_S1_AACAGGGTCCATAGAC-1 16
# WT_S1_AACCACACAGACACCC-1 36
# WT_S1_AAGACAACACATATGC-1 14
# WT_S1_AAGACTCTCAAAGGAT-1 18
# WT_S1_AAGGTAATCCTGTACC-1 30
# WT_S1_AAGTTCGTCTACCCAC-1 38
# WT_S1_AATCGTGTCGGCCAAC-1 31
# WT_S1_AATGGCTTCTCATGGA-1 32
# WT_S1_AATTTCCGTTTACTTC-1 33
# WT_S1_AGACACTGTACCTTCC-1 34
# WT_S1_ATTACTCTCAGCACCG-1 35

# %%
# user can enter the classification if it is dividing a cluster that should not be divided
# e.g., "DIM, RhomS3PRadial Glia (Bergmann Glia)" and "radial glia" is dividing the cluster into 2 when it should be only 1 
class = readline(prompt = "Input the simple classification in lower case, e.g. radial glia:")
# Out:
# Input the simple classification in lower case, e.g. radial glia: radial glia

# %%
# convert the sctype_classification column to lower case
LOG_NORM_NOVOALL_filt_final@meta.data %>% 
                                            mutate(sctype_classification = tolower(sctype_classification)) %>%
                                            mutate(sctype_classification = 
                                                   ifelse(str_detect(sctype_classification, class), class,  # replace with user input
                                                          sctype_classification)) # otherwise
# Out:
# Error in LOG_NORM_NOVOALL_filt_final@meta.data %>% mutate(sctype_classification = tolower(sctype_classification)) %>% : could not find function "%>%"
# Traceback:
